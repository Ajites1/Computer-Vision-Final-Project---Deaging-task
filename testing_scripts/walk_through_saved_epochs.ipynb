# %%
import os
import numpy as np
import glob
import torch
directory_path = "/projects/standard/csci5561/shared/G8/testing_scripts/epochs_attempt1" 
device = 'cpu'

# %%
for root, dirs, files in os.walk(directory_path):
    for filename in files:
        path = os.path.join(root, filename)
        checkpoint = torch.load(path, map_location=device)
        print(f"Loaded checkpoint from epoch {checkpoint['epoch']}")
        print(f"Cross-sectional loss: {checkpoint['loss_cross']:.4f}")
        print(f"Longitudinal loss: {checkpoint['loss_long']:.4f}\n\n")
# Out:
# /tmp/ipykernel_3099613/16154601.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=device)
# Loaded checkpoint from epoch 14
# Cross-sectional loss: 0.0050
# Longitudinal loss: 0.0089
#
#
# Loaded checkpoint from epoch 19
# Cross-sectional loss: 0.0050
# Longitudinal loss: 0.0087
#
#
# Loaded checkpoint from epoch 24
# Cross-sectional loss: 0.0049
# Longitudinal loss: 0.0087
#
#
# Loaded checkpoint from epoch 29
# Cross-sectional loss: 0.0049
# Longitudinal loss: 0.0085
#
#
# Loaded checkpoint from epoch 34
# Cross-sectional loss: 0.0048
# Longitudinal loss: 0.0086
#
#
# Loaded checkpoint from epoch 39
# Cross-sectional loss: 0.0047
# Longitudinal loss: 0.0084
#
#
# Loaded checkpoint from epoch 4
# Cross-sectional loss: 0.0057
# Longitudinal loss: 0.0096
#
#
# Loaded checkpoint from epoch 44
# Cross-sectional loss: 0.0048
# Longitudinal loss: 0.0084
#
#
# Loaded checkpoint from epoch 49
# Cross-sectional loss: 0.0046
# Longitudinal loss: 0.0086
#
#
# Loaded checkpoint from epoch 54
# Cross-sectional loss: 0.0047
# Longitudinal loss: 0.0086
#
#
# Loaded checkpoint from epoch 59
# Cross-sectional loss: 0.0048
# Longitudinal loss: 0.0083
#
#
# Loaded checkpoint from epoch 64
# Cross-sectional loss: 0.0047
# Longitudinal loss: 0.0082
#
#
# Loaded checkpoint from epoch 69
# Cross-sectional loss: 0.0046
# Longitudinal loss: 0.0080
#
#
# Loaded checkpoint from epoch 74
# Cross-sectional loss: 0.0046
# Longitudinal loss: 0.0083
#
#
# Loaded checkpoint from epoch 79
# Cross-sectional loss: 0.0046
# Longitudinal loss: 0.0080
#
#
# Loaded checkpoint from epoch 84
# Cross-sectional loss: 0.0046
# Longitudinal loss: 0.0084
#
#
# Loaded checkpoint from epoch 89
# Cross-sectional loss: 0.0046
# Longitudinal loss: 0.0082
#
#
# Loaded checkpoint from epoch 9
# Cross-sectional loss: 0.0053
# Longitudinal loss: 0.0087
#
#
# Loaded checkpoint from epoch 94
# Cross-sectional loss: 0.0047
# Longitudinal loss: 0.0082
#
#
# Loaded checkpoint from epoch 99
# Cross-sectional loss: 0.0046
# Longitudinal loss: 0.0086
